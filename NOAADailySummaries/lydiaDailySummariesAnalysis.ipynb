# %%
import pandas as pd

# %%
data = pd.read_json("NOAADailySummariesJSON/Combined.json")

# %%
data
# Out:
#            date datatype            station attributes  value
# 0    2018-01-01     PRCP  GHCND:US1DENC0001   ,,N,0700      0
# 1    2018-01-01     SNWD  GHCND:US1DENC0001  T,,N,0700      0
# 2    2018-01-01     PRCP  GHCND:US1DENC0002   ,,N,0700      0
# 3    2018-01-01     SNOW  GHCND:US1DENC0002   ,,N,0700      0
# 4    2018-01-01     SNWD  GHCND:US1DENC0002  T,,N,0700      0
# ...         ...      ...                ...        ...    ...
# 1382 2018-01-31     TMIN  GHCND:USW00013781   ,,W,2400    -93
# 1383 2018-01-31     WDF2  GHCND:USW00013781       ,,W,    320
# 1384 2018-01-31     WDF5  GHCND:USW00013781       ,,W,    310
# 1385 2018-01-31     WSF2  GHCND:USW00013781       ,,W,     89
# 1386 2018-01-31     WSF5  GHCND:USW00013781       ,,W,    116
#
# [1387 rows x 5 columns]

# %% [markdown]
# How many stations are there in total for FIPS10003?

# %%
station_count = data['station'].unique()

# %%
len(station_count)
# Out:
# 17

# %% [markdown]
# Create a DataFrame called temps_max that only contains the entries from df_daily_summaries where the datatype column is equal to TMAX. This DataFrame should only retain the date column and the value column.

# %%
temps_max = data[data["datatype"].str.contains("TMAX")][["date", "value"]]

# %%
temps_max
# Out:
#            date  value
# 42   2018-01-01    -60
# 89   2018-01-02    -38
# 138  2018-01-03     -5
# 193  2018-01-04    -21
# 240  2018-01-05    -82
# 279  2018-01-06    -88
# 322  2018-01-07    -71
# 365  2018-01-08      6
# 399  2018-01-09     78
# 443  2018-01-10     56
# 488  2018-01-11    133
# 529  2018-01-12    167
# 577  2018-01-13    139
# 621  2018-01-14    -32
# 670  2018-01-15      0
# 720  2018-01-16     56
# 773  2018-01-17     22
# 819  2018-01-18     22
# 864  2018-01-19     83
# 908  2018-01-20    139
# 955  2018-01-21    117
# 993  2018-01-22    156
# 1034 2018-01-23    172
# 1077 2018-01-24     72
# 1120 2018-01-25     28
# 1164 2018-01-26     39
# 1207 2018-01-27    150
# 1243 2018-01-28    133
# 1292 2018-01-29     78
# 1335 2018-01-30     39
# 1381 2018-01-31      6

# %% [markdown]
# How many entries are there in the temps_max DataFrame? What are the mean, min, and max values?

# %%
len(temps_max)
# Out:
# 31

# %%
temps_max["value"].mean()
# Out:
# 48.193548387096776

# %%
temps_max["value"].min()
# Out:
# -88

# %%
temps_max["value"].max()
# Out:
# 172

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = [x.day for x in temps_max['date']]
y = temps_max['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Max Temperatures Jan 2018')
# Out:
# [Text(0.5, 0, 'day of month'),
#  Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 1.0, 'Max Temperatures Jan 2018')]

# %% [markdown]
# Create a DataFrame called temps_min that only contains the entries from df_daily_summaries where the datatype column is equal to TMIN. This DataFrame should only retain the date column and the value column.

# %%
temps_min = data[data["datatype"].str.contains("TMIN")][["date", "value"]]

# %%
temps_min
# Out:
#            date  value
# 43   2018-01-01   -149
# 90   2018-01-02   -116
# 139  2018-01-03   -132
# 194  2018-01-04    -93
# 241  2018-01-05   -121
# 280  2018-01-06   -138
# 323  2018-01-07   -166
# 366  2018-01-08   -105
# 400  2018-01-09    -60
# 444  2018-01-10    -49
# 489  2018-01-11     33
# 530  2018-01-12     83
# 578  2018-01-13    -71
# 622  2018-01-14   -105
# 671  2018-01-15    -88
# 721  2018-01-16    -16
# 774  2018-01-17    -77
# 820  2018-01-18    -99
# 865  2018-01-19    -66
# 909  2018-01-20    -38
# 956  2018-01-21    -32
# 994  2018-01-22     39
# 1035 2018-01-23     44
# 1078 2018-01-24      6
# 1121 2018-01-25    -38
# 1165 2018-01-26    -66
# 1208 2018-01-27    -49
# 1244 2018-01-28     72
# 1293 2018-01-29     33
# 1336 2018-01-30    -55
# 1382 2018-01-31    -93

# %% [markdown]
# How many entries are there in the temps_min DataFrame? What are the mean, min, and max values?

# %%
len(temps_min)
# Out:
# 31

# %%
temps_min["value"].mean()
# Out:
# -55.225806451612904

# %%
temps_min["value"].min()
# Out:
# -166

# %%
temps_min["value"].max()
# Out:
# 83

# %%
x = [x.day for x in temps_min['date']]
y = temps_min['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min Temperatures Jan 2018')
# Out:
# [Text(0.5, 0, 'day of month'),
#  Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 1.0, 'Min Temperatures Jan 2018')]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20,10)
ax.plot(x, temps_max['value'] / 10, color='red')
ax.plot(x, temps_min['value'] / 10, color='blue')
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min & Max Temperatures Jan 2018')
# Out:
# [Text(0.5, 0, 'day of month'),
#  Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 1.0, 'Min & Max Temperatures Jan 2018')]
